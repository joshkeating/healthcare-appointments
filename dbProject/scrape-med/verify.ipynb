# %%
import pandas as pd

# %%
tmp = pd.read_csv('./medications-clean.csv')

# %%
tmp
# Out:
#           Acetaminophen  \
# 0              Adderall
# 1            Alprazolam
# 2         Amitriptyline
# 3            Amlodipine
# 4           Amoxicillin
# 5                Ativan
# 6          Atorvastatin
# 7          Azithromycin
# 8         Ciprofloxacin
# 9            Citalopram
# 10          Clindamycin
# 11           Clonazepam
# 12              Codeine
# 13      Cyclobenzaprine
# 14             Cymbalta
# 15          Doxycycline
# 16           Gabapentin
# 17  Hydrochlorothiazide
# 18            Ibuprofen
# 19              Lexapro
# 20           Lisinopril
# 21           Loratadine
# 22            Lorazepam
# 23             Losartan
# 24               Lyrica
# 25            Meloxicam
# 26            Metformin
# 27           Metoprolol
# 28             Naproxen
# 29           Omeprazole
# 30            Oxycodone
# 31         Pantoprazole
# 32           Prednisone
# 33             Tramadol
# 34            Trazodone
# 35               Viagra
# 36           Wellbutrin
# ...
